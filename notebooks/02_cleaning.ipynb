# %% [markdown]
# # Cleaning
# ---
# 1. Duplicates dropping.
#
# 2. Categorical cleaning.
#
# 3. Outliers handling.
#
# 4. Feature extraction
#
# 5. Column Redundancy handling.
#
# 6. Data types handling.
#
# 7. Saving our cleaned data
# ---
# ### **Before cleaning:** (4801, 17)
# ### **After cleaning:** (3958, 9)
# ---

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"../data/raw/NY-House-Dataset.csv")
df_copy = df.copy()

# %% [markdown]
# #### Duplicates

# %%
df_copy.duplicated().sum()
# Out:
# 214

# %%
df_copy.drop_duplicates(inplace=True)

# %%
df_copy.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Categorical Cleaning

# %%
df_copy.select_dtypes(include=['object']).nunique()
# Out:
# BROKERTITLE                    1036
# TYPE                             13
# ADDRESS                        4582
# STATE                           308
# MAIN_ADDRESS                   4583
# ADMINISTRATIVE_AREA_LEVEL_2      29
# LOCALITY                         11
# SUBLOCALITY                      21
# STREET_NAME                     174
# LONG_NAME                      2731
# FORMATTED_ADDRESS              4550
# dtype: int64

# %%
df_copy["TYPE"].value_counts()
# Out:
# TYPE
# Co-op for sale                1388
# House for sale                 966
# Condo for sale                 842
# Multi-family home for sale     699
# Townhouse for sale             288
# Pending                        229
# Contingent                      87
# Land for sale                   47
# For sale                        20
# Foreclosure                     14
# Condop for sale                  4
# Coming Soon                      2
# Mobile house for sale            1
# Name: count, dtype: int64

# %%
df_copy['TYPE'] = df_copy['TYPE'].str.strip()

type_mapping = {
    'Condop for sale': 'Condop',
    'House for sale': 'House',
    'Condo for sale': 'Condo',
    'Co-op for sale': 'Co-op',
    'Townhouse for sale': 'Townhouse',
    'Multi-family home for sale': 'Multi-family home',
    "Land for sale": "Land"
}

df_copy['TYPE'] = df_copy['TYPE'].replace(type_mapping)

status_types = ["Foreclosure", "For sale", "Pending", "Contingent", "Coming Soon"]
df_copy = df_copy[~df_copy['TYPE'].isin(status_types)]

# %%
df_copy.shape
# Out:
# (4235, 17)

# %%
df_copy["STATE"].value_counts()
# Out:
# STATE
# Brooklyn, NY 11235         96
# Brooklyn, NY 11234         84
# Forest Hills, NY 11375     84
# Brooklyn, NY 11209         84
# Staten Island, NY 10314    70
#                            ..
# Manhattan, NY 10006         1
# New York, NY 10309          1
# Hollis, NY 11432            1
# Flushing, NY 11357          1
# Ozone Park, NY 11416        1
# Name: count, Length: 300, dtype: int64

# %%
mapping = {
    'Flatbush': 'Brooklyn',
    'Kings County': 'Brooklyn',
    'New York County': 'Manhattan',
    'New York': 'Manhattan',
    'Queens County': 'Queens',
    'Bronx County': 'Bronx',
    'The Bronx': 'Bronx',
    'Richmond County': 'Staten Island'
}

df_copy['LOCALITY'] = df_copy['LOCALITY'].replace(mapping)

# %%
df_copy.LOCALITY.value_counts()
# Out:
# LOCALITY
# Manhattan        3048
# Queens            521
# Brooklyn          414
# Bronx             171
# Staten Island      46
# United States      35
# Name: count, dtype: int64

# %%
df_copy[df_copy["LOCALITY"] == "United States"]
# Out:
#                                             BROKERTITLE               TYPE  \
# 27                  Brokered by Century 21 Realty First  Multi-family home
# 4778  40.598830 -73.985964

# %%
df_copy['STATE'] = df_copy['STATE'].str.strip()

mask = df_copy['LOCALITY'] == 'United States'
df_copy.loc[mask, 'LOCALITY'] = df_copy.loc[mask, 'STATE'].str.split(',').str[0]
mapping = {
    'Howard Beach': 'Queens',
    'Saint Albans': 'Queens',
    'New York': 'Manhattan'
}
df_copy['LOCALITY'] = df_copy['LOCALITY'].replace(mapping)


df_copy['LOCALITY'].value_counts()
# Out:
# LOCALITY
# Manhattan        3054
# Queens            524
# Brooklyn          428
# Bronx             176
# Staten Island      53
# Name: count, dtype: int64

# %%
df_copy["SUBLOCALITY"].value_counts()
# Out:
# SUBLOCALITY
# New York            904
# Kings County        641
# Queens County       605
# Queens              513
# Brooklyn            407
# Richmond County     370
# Bronx County        284
# New York County     258
# The Bronx           169
# Staten Island        46
# Manhattan            21
# Flushing              4
# Coney Island          3
# Riverdale             3
# East Bronx            1
# Brooklyn Heights      1
# Jackson Heights       1
# Rego Park             1
# Fort Hamilton         1
# Dumbo                 1
# Snyder Avenue         1
# Name: count, dtype: int64

# %%
df_copy["LONG_NAME"].value_counts()
# Out:
# LONG_NAME
# 200                  18
# 2                    17
# 100                  16
# 50                   15
# 40                   14
#                      ..
# West 144th Street     1
# 37th Road             1
# West 28th Street      1
# Zerega Avenue         1
# 2351                  1
# Name: count, Length: 2577, dtype: int64

# %% [markdown]
# #### Outliers

# %%
for column in df_copy.select_dtypes(include=np.number).columns:

    Q1 = df_copy[column].quantile(0.25)
    Q3 = df_copy[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    ouliers_mask = (df_copy[column] < lower_bound) | (df_copy[column] > upper_bound)

    print(f"Column: {column}, Outliers: {ouliers_mask.sum()}")
# Out:
# Column: PRICE, Outliers: 489
# Column: BEDS, Outliers: 209
# Column: BATH, Outliers: 104
# Column: PROPERTYSQFT, Outliers: 351
# Column: LATITUDE, Outliers: 0
# Column: LONGITUDE, Outliers: 132

# %%
df_copy.LONGITUDE.describe()
# It seems that there are all valid longitude values
# No outliers detected
# Out:
# count    4235.000000
# mean      -73.937999
# std         0.098287
# min       -74.253033
# 25%       -73.984988
# 50%       -73.947266
# 75%       -73.867658
# max       -73.702450
# Name: LONGITUDE, dtype: float64

# %%
df_copy.BATH.astype(str).value_counts()
# 2.3738608579684373 must be the mean value imputed previously
# Out:
# BATH
# 2.0                   1453
# 1.0                   1355
# 3.0                    420
# 4.0                    419
# 2.3738608579684373     265
# 6.0                    128
# 5.0                     90
# 8.0                     43
# 7.0                     21
# 10.0                    15
# 9.0                      6
# 16.0                     5
# 20.0                     3
# 12.0                     3
# 11.0                     2
# 24.0                     1
# 0.0                      1
# 43.0                     1
# 32.0                     1
# 50.0                     1
# 13.0                     1
# 17.0                     1
# Name: count, dtype: int64

# %%
df_copy = df_copy[(df_copy['BATH'] != 2.3738608579684373) & (df_copy['BATH'] != 0)]

# %%
df_copy.PROPERTYSQFT.astype(str).value_counts()
# 2184.207862 must be the mean value imputed previously
# This is a disaster, about 1300 entries have this value
# Out:
# PROPERTYSQFT
# 2184.207862    1324
# 800.0            51
# 750.0            48
# 900.0            47
# 1200.0           40
#                ...
# 2324.0            1
# 5103.0            1
# 1541.0            1
# 2042.0            1
# 655.0             1
# Name: count, Length: 1293, dtype: int64

# %%
df_copy["PROPERTYSQFT"] = df_copy["PROPERTYSQFT"].replace(2184.207862, np.nan)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3969 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  3969 non-null   object
#  1   TYPE                         3969 non-null   object
#  2   PRICE                        3969 non-null   int64
#  3   BEDS                         3969 non-null   int64
#  4   BATH                         3969 non-null   float64
#  5   PROPERTYSQFT                 2645 non-null   float64
#  6   ADDRESS                      3969 non-null   object
#  7   STATE                        3969 non-null   object
#  8   MAIN_ADDRESS                 3969 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  3969 non-null   object
#  10  LOCALITY                     3969 non-null   object
#  11  SUBLOCALITY                  3969 non-null   object
#  12  STREET_NAME                  3969 non-null   object
#  13  LONG_NAME                    3969 non-null   object
#  14  FORMATTED_ADDRESS            3969 non-null   object
#  15  LATITUDE                     3969 non-null   float64
#  16  LONGITUDE                    3969 non-null   float64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 558.1+ KB

# %%
df_copy["PROPERTYSQFT"] = df_copy["PROPERTYSQFT"].fillna(
    df_copy.groupby(["LOCALITY", "TYPE"])["PROPERTYSQFT"].transform("mean").apply(np.ceil)
)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3969 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  3969 non-null   object
#  1   TYPE                         3969 non-null   object
#  2   PRICE                        3969 non-null   int64
#  3   BEDS                         3969 non-null   int64
#  4   BATH                         3969 non-null   float64
#  5   PROPERTYSQFT                 3963 non-null   float64
#  6   ADDRESS                      3969 non-null   object
#  7   STATE                        3969 non-null   object
#  8   MAIN_ADDRESS                 3969 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  3969 non-null   object
#  10  LOCALITY                     3969 non-null   object
#  11  SUBLOCALITY                  3969 non-null   object
#  12  STREET_NAME                  3969 non-null   object
#  13  LONG_NAME                    3969 non-null   object
#  14  FORMATTED_ADDRESS            3969 non-null   object
#  15  LATITUDE                     3969 non-null   float64
#  16  LONGITUDE                    3969 non-null   float64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 558.1+ KB

# %%
df_copy.PROPERTYSQFT.astype(str).value_counts()
# I think it's better now.
# Out:
# PROPERTYSQFT
# 1440.0    425
# 964.0     225
# 2230.0    225
# 3262.0    221
# 4087.0     52
#          ...
# 2042.0      1
# 2205.0      1
# 1810.0      1
# 1530.0      1
# 655.0       1
# Name: count, Length: 1299, dtype: int64

# %%
df_copy.BEDS.astype(str).value_counts()
# Out:
# BEDS
# 3     1128
# 2      879
# 1      725
# 4      467
# 5      277
# 6      215
# 7       83
# 8       67
# 9       34
# 10      20
# 11      19
# 12      19
# 14       6
# 15       5
# 13       5
# 16       4
# 20       3
# 24       3
# 32       2
# 35       1
# 50       1
# 36       1
#
#      ADMINISTRATIVE_AREA_LEVEL_2   LOCALITY      SUBLOCALITY    STREET_NAME  \
# 1                  United States  Manhattan  New York County       New York
# 99                 United States  Manhattan  New York County       New York
# 141                United States  Manhattan  New York County       New York
# 304                United States  Manhattan  Richmond County  Staten Island
# 1075                    New York  Manhattan         New York      Manhattan
#
#              LONG_NAME                            FORMATTED_ADDRESS  \
# 1     West 57th Street       217 W 57th St, New York, NY 10019, USA
# 99     Riverside Drive     25 Riverside Dr, New York, NY 10023, USA
# 141   West 54th Street         9 W 54th St, New York, NY 10019, USA
# 304         Amboy Road  6659 Amboy Rd, Staten Island, NY 10309, USA
# 1075               960     960 5th Ave #12, New York, NY 10075, USA
#
#        LATITUDE  LONGITUDE
# 1     40.766393 -73.980991
# 99    40.782238 -73.984632
# 141   40.761600 -73.976191
# 304   40.518484 -74.224418
# 1075  40.775642 -73.964247

# %%
print("Before cleaning price outliers:", df_copy.shape)
df_copy = df_copy[df_copy["PRICE"] < 2_000_000_000]

df_copy["price_per_sqft"] = df_copy["PRICE"] / df_copy["PROPERTYSQFT"]
df_copy = df_copy[df_copy["price_per_sqft"] < 20000]

df_copy = df_copy[df_copy["PROPERTYSQFT"] > 100]

df_copy.drop(columns=["price_per_sqft"], inplace=True)

print("After cleaning price outliers:", df_copy.shape)
# Out:
# Before cleaning price outliers: (3969, 17)
# After cleaning price outliers: (3959, 17)

# %%
df_copy[df_copy["PRICE"] > 50_000_000]
# Out:
#                                        BROKERTITLE   TYPE      PRICE  BEDS  \
# 1                              Brokered by Serhant  Condo  195000000     7
# 99   Brokered by Douglas Elliman - 575 Madison Ave  House   55000000     8
# 141  Brokered by Douglas Elliman - 575 Madison Ave  House   56000000    11
#
#      BATH  PROPERTYSQFT                                            ADDRESS  \
# 1    10.0       17545.0  Central Park Tower Penthouse-217 W 57th New Yo...
# 99    8.0       12000.0                                    25 Riverside Dr
# 141  10.0       24000.0                                        9 W 54th St
#
#                   STATE                                       MAIN_ADDRESS  \
# 1    New York, NY 10019  Central Park Tower Penthouse-217 W 57th New Yo...
# 99   New York, NY 10023                  25 Riverside DrNew York, NY 10023
# 141  New York, NY 10019                      9 W 54th StNew York, NY 10019
#
#     ADMINISTRATIVE_AREA_LEVEL_2   LOCALITY      SUBLOCALITY STREET_NAME  \
# 1                 United States  Manhattan  New York County    New York
# 99                United States  Manhattan  New York County    New York
# 141               United States  Manhattan  New York County    New York
#
#             LONG_NAME                         FORMATTED_ADDRESS   LATITUDE  \
# 1    West 57th Street    217 W 57th St, New York, NY 10019, USA  40.766393
# 99    Riverside Drive  25 Riverside Dr, New York, NY 10023, USA  40.782238
# 141  West 54th Street      9 W 54th St, New York, NY 10019, USA  40.761600
#
#      LONGITUDE
# 1   -73.980991
# 99  -73.984632
# 141 -73.976191

# %%
df_copy = df_copy[df_copy['LATITUDE'].between(40.4, 41.0)]
df_copy = df_copy[df_copy['LONGITUDE'].between(-74.3, -73.6)]

# %%
df_copy["TYPE"].value_counts()
# We have only 1 land type, we can drop it
df_copy = df_copy[df_copy["TYPE"] != "Land"]

# %%
# Before cleaning outliers:
# Column: PRICE, Outliers: 489
# Column: BEDS, Outliers: 209
# Column: BATH, Outliers: 104
# Column: PROPERTYSQFT, Outliers: 351
# Column: LATITUDE, Outliers: 0
# Column: LONGITUDE, Outliers: 132
# After cleaning outliers:
for column in df_copy.select_dtypes(include=np.number).columns:

    Q1 = df_copy[column].quantile(0.25)
    Q3 = df_copy[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    ouliers_mask = (df_copy[column] < lower_bound) | (df_copy[column] > upper_bound)

    print(f"Column: {column}, Outliers: {ouliers_mask.sum()}")
# Out:
# Column: PRICE, Outliers: 453
# Column: BEDS, Outliers: 194
# Column: BATH, Outliers: 103
# Column: PROPERTYSQFT, Outliers: 217
# Column: LATITUDE, Outliers: 0
# Column: LONGITUDE, Outliers: 113

# %% [markdown]
# #### Feature extraction

# %%
df_copy.head()
# Out:
#                                    BROKERTITLE   TYPE      PRICE  BEDS  BATH  \
# 0  Brokered by Douglas Elliman  -111 Fifth Ave  Condo     315000     2   2.0
# 1                          Brokered by Serhant  Condo  195000000     7  10.0
# 2                       Brokered by Sowae Corp  House     260000     4   2.0
# 3                          Brokered by COMPASS  Condo      69000     3   1.0
# 5                       Brokered by Sowae Corp  House     690000     5   2.0
#
#    PROPERTYSQFT                                            ADDRESS  \
# 0        1400.0                               2 E 55th St Unit 803
# 1       17545.0  Central Park Tower Penthouse-217 W 57th New Yo...
# 2        2015.0                                   620 Sinclair Ave
# 3         445.0                            2 E 55th St Unit 908W33
# 5        4004.0                                        584 Park Pl
#
#                      STATE                                       MAIN_ADDRESS  \
# 0       New York, NY 10022             2 E 55th St Unit 803New York, NY 10022
# 1       New York, NY 10019  Central Park Tower Penthouse-217 W 57th New Yo...
# 2  Staten Island, NY 10312            620 Sinclair AveStaten Island, NY 10312
# 3      Manhattan, NY 10022         2 E 55th St Unit 908W33Manhattan, NY 10022
# 5       Brooklyn, NY 11238                      584 Park PlBrooklyn, NY 11238
#
#   ADMINISTRATIVE_AREA_LEVEL_2   LOCALITY      SUBLOCALITY       STREET_NAME  \
# 0             New York County  Manhattan        Manhattan  East 55th Street
# 1               United States  Manhattan  New York County          New York
# 2               United States  Manhattan  Richmond County     Staten Island
# 3               United States  Manhattan  New York County          New York
# 5               United States  Manhattan     Kings County          Brooklyn
#
#           LONG_NAME                                  FORMATTED_ADDRESS  \
# 0   Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...
# 1  West 57th Street             217 W 57th St, New York, NY 10019, USA
# 2   Sinclair Avenue     620 Sinclair Ave, Staten Island, NY 10312, USA
# 3  East 55th Street               2 E 55th St, New York, NY 10022, USA
# 5        Park Place               584 Park Pl, Brooklyn, NY 11238, USA
#
#     LATITUDE  LONGITUDE
# 0  40.761255 -73.974483
# 1  40.766393 -73.980991
# 2  40.541805 -74.196109
# 3  40.761398 -73.974613
# 5  40.674363 -73.958725

# %%
df_copy["ZIPCODE"] = df_copy["STATE"].str.extract(r'(\d{5})')

# %%
def calculate_distance(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    return 6371 * c

# Timez Square coordinates as the center of New York
TIMES_SQUARE_LAT = 40.7588
TIMES_SQUARE_LON = -73.9851

df_copy['DISTANCE_TO_CENTER'] = df_copy.apply(
    lambda row: calculate_distance(row['LATITUDE'], row['LONGITUDE'], TIMES_SQUARE_LAT, TIMES_SQUARE_LON), 
    axis=1
)

# Wall Street coordinates
WALL_STREET_LAT = 40.7060
WALL_STREET_LON = -74.0088

df_copy['DISTANCE_TO_WALL_STREET'] = df_copy.apply(
    lambda row: calculate_distance(row['LATITUDE'], row['LONGITUDE'], WALL_STREET_LAT, WALL_STREET_LON), 
    axis=1
)

# %% [markdown]
# #### Column Redundancy

# %%
df_copy.columns
# Out:
# Index(['BROKERTITLE', 'TYPE', 'PRICE', 'BEDS', 'BATH', 'PROPERTYSQFT',
#        'ADDRESS', 'STATE', 'MAIN_ADDRESS', 'ADMINISTRATIVE_AREA_LEVEL_2',
#        'LOCALITY', 'SUBLOCALITY', 'STREET_NAME', 'LONG_NAME',
#        'FORMATTED_ADDRESS', 'LATITUDE', 'LONGITUDE', 'ZIPCODE',
#        'DISTANCE_TO_CENTER', 'DISTANCE_TO_WALL_STREET'],
#       dtype='object')

# %%
df_copy = df_copy.rename(columns=lambda x: x.lower())
df_copy.columns
# Out:
# Index(['brokertitle', 'type', 'price', 'beds', 'bath', 'propertysqft',
#        'address', 'state', 'main_address', 'administrative_area_level_2',
#        'locality', 'sublocality', 'street_name', 'long_name',
#        'formatted_address', 'latitude', 'longitude', 'zipcode',
#        'distance_to_center', 'distance_to_wall_street'],
#       dtype='object')

# %%
df_copy = df_copy[[
       # 'brokertitle',
       'type', 'price', 'beds', 'bath', 'propertysqft',
       # 'address', 'state', 'main_address', 'administrative_area_level_2',
       'locality',
       # 'sublocality', 'street_name', 'long_name',
       # 'formatted_address', 'latitude', 'longitude',
       'zipcode', 'distance_to_center', 'distance_to_wall_street']]

# %%
df_copy.shape
# Out:
# (3958, 9)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3958 entries, 0 to 4800
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     3958 non-null   object
#  1   price                    3958 non-null   int64
#  2   beds                     3958 non-null   int64
#  3   bath                     3958 non-null   float64
#  4   propertysqft             3958 non-null   float64
#  5   locality                 3958 non-null   object
#  6   zipcode                  3958 non-null   object
#  7   distance_to_center       3958 non-null   float64
#  8   distance_to_wall_street  3958 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 309.2+ KB

# %% [markdown]
# #### Data types

# %%
df_copy.dtypes
# Out:
# type                        object
# price                        int64
# beds                         int64
# bath                       float64
# propertysqft               float64
# locality                    object
# zipcode                     object
# distance_to_center         float64
# distance_to_wall_street    float64
# dtype: object

# %%
df_copy.bath = df_copy.bath.astype(int)
df_copy.type = df_copy.type.astype("category")
df_copy.locality = df_copy.locality.astype("category")

# %% [markdown]
# #### Saving cleaned data

# %%
df_final = df_copy.reset_index(drop=True)
df_final.to_csv(r"../data/cleaned/NY-House-Cleaned-Dataset.csv", index=False)
